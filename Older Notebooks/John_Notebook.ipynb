# %% [markdown]
# ## Initial Commit

# %%
import surprise
from surprise.prediction_algorithms import *
import pandas as pd
import numpy as np
import datetime as dt

# %%
link_df = pd.read_csv('data/links.csv')
movies_df = pd.read_csv('data/movies.csv')
ratings_df = pd.read_csv('data/ratings.csv')
tags_df = pd.read_csv('data/tags.csv')

# %%
link_df
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
movies_df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
ratings_df
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
tags_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   userId     3683 non-null   int64
#  1   movieId    3683 non-null   int64
#  2   tag        3683 non-null   object
#  3   timestamp  3683 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 115.2+ KB

# %%
tags_df['userId'] = tags_df['userId'].apply(str)
tags_df['movieId'] = tags_df['movieId'].apply(str)
tags_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   userId     3683 non-null   object
#  1   movieId    3683 non-null   object
#  2   tag        3683 non-null   object
#  3   timestamp  3683 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 115.2+ KB

# %%
tags_df['userId_movieId'] = tags_df['userId'] + tags_df['movieId']
tags_df
# Out:
#      userId movieId               tag   timestamp userId_movieId
# 0         2   60756             funny  1445714994         260756
# 1         2   60756   Highly quotable  1445714996         260756
# 2         2   60756      will ferrell  1445714992         260756
# 3         2   89774      Boxing story  1445715207         289774
# 4         2   89774               MMA  1445715200         289774
# ...     ...     ...               ...         ...            ...
# 3678    606    7382         for katie  1171234019        6067382
# 3679    606    7936           austere  1173392334        6067936
# 3680    610    3265            gun fu  1493843984        6103265
# 3681    610    3265  heroic bloodshed  1493843978        6103265
# 3682    610  168248  Heroic Bloodshed  1493844270      610168248
#
# [3683 rows x 5 columns]

# %%
tags_df['userId'] = tags_df['userId'].apply(int)
tags_df['movieId'] = tags_df['movieId'].apply(int)
tags_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3683 entries, 0 to 3682
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   userId          3683 non-null   int64
#  1   movieId         3683 non-null   int64
#  2   tag             3683 non-null   object
#  3   timestamp       3683 non-null   int64
#  4   userId_movieId  3683 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 144.0+ KB

# %%
tags_df['userId_movieId'][tags_df['userId_movieId'].duplicated(keep=False)]
# Out:
# 0        260756
# 1        260756
# 2        260756
# 3        289774
# 4        289774
#          ...
# 3669    5992959
# 3670    5992959
# 3671    5992959
# 3680    6103265
# 3681    6103265
# Name: userId_movieId, Length: 2510, dtype: object

# %%
#https://stackoverflow.com/questions/44397210/drop-duplicates-and-add-values-pandas

f = {c: ' '.join if c == 'tag' else 'first' for c in ['userId', 'movieId', 'timestamp', 'tag']}

tags_df = tags_df.groupby(
    tags_df.userId_movieId.astype(str), sort=False
).agg(f).reset_index().eval(
    'userId_movieId = @pd.to_numeric(userId_movieId, "coerce").values',
    inplace=False
)

# %%
tags_df
# Out:
#       userId_movieId  userId  movieId   timestamp  \
# 0             260756       2    60756  1445714994
# 1             289774       2    89774  1445715207
# 2            2106782       2   106782  1445715054
# 3             748516       7    48516  1169687325
# 4              18431      18      431  1462138765
# ...              ...     ...      ...         ...
# 1770         6066107     606     6107  1178473747
# 1771         6067382     606     7382  1171234019
# 1772         6067936     606     7936  1173392334
# 1773         6103265     610     3265  1493843984
# 1774       610168248     610   168248  1493844270
#
#                                           tag
# 0          funny Highly quotable will ferrell
# 1                  Boxing story MMA Tom Hardy
# 2     drugs Leonardo DiCaprio Martin Scorsese
# 3                                way too long
# 4                    Al Pacino gangster mafia
# ...                                       ...
# 1770                             World War II
# 1771                                for katie
# 1772                                  austere
# 1773                  gun fu heroic bloodshed
# 1774                         Heroic Bloodshed
#
# [1775 rows x 5 columns]

# %%
ratings_movie_df = ratings_df.merge(movies_df, on  = 'movieId')
ratings_movie_df
# Out:
#         userId  movieId  rating   timestamp                             title  \
# 0            1        1     4.0   964982703                  Toy Story (1995)
# 1            5        1     4.0   847434962                  Toy Story (1995)
# 2            7        1     4.5  1106635946                  Toy Story (1995)
# 3           15        1     2.5  1510577970                  Toy Story (1995)
# 4           17        1     4.5  1305696483                  Toy Story (1995)
# ...        ...      ...     ...         ...                               ...
# 100831     610   160341     2.5  1479545749                  Bloodmoon (1997)
# 100832     610   160527     4.5  1479544998  Sympathy for the Underdog (1971)
# 100833     610   160836     3.0  1493844794                     Hazard (2005)
# 100834     610   163937     3.5  1493848789                Blair Witch (2016)
# 100835     610   163981     3.5  1493850155                         31 (2016)
#
#                                              genres
# 0       Adventure|Animation|Children|Comedy|Fantasy
# 1       Adventure|Animation|Children|Comedy|Fantasy
# 2       Adventure|Animation|Children|Comedy|Fantasy
# 3       Adventure|Animation|Children|Comedy|Fantasy
# 4       Adventure|Animation|Children|Comedy|Fantasy
# ...                                             ...
# 100831                              Action|Thriller
# 100832                           Action|Crime|Drama
# 100833                        Action|Drama|Thriller
# 100834                              Horror|Thriller
# 100835                                       Horror
#
# [100836 rows x 6 columns]

# %%
ratings_movie_tags_df = ratings_movie_df.merge(tags_df, left_on = ['movieId', 'userId'], right_on = ['movieId', 'userId'], how = 'left')

# %%
ratings_movie_tags_df
# Out:
#         userId  movieId  rating  timestamp_x  \
# 0            1        1     4.0    964982703
# 1            5        1     4.0    847434962
# 2            7        1     4.5   1106635946
# 3           15        1     2.5   1510577970
# 4           17        1     4.5   1305696483
# ...        ...      ...     ...          ...
# 100831     610   160341     2.5   1479545749
# 100832     610   160527     4.5   1479544998
# 100833     610   160836     3.0   1493844794
# 100834     610   163937     3.5   1493848789
# 100835     610   163981     3.5   1493850155
#
#                                    title  \
# 0                       Toy Story (1995)
# 1                       Toy Story (1995)
# 2                       Toy Story (1995)
# 3                       Toy Story (1995)
# 4                       Toy Story (1995)
# ...                                  ...
# 100831                  Bloodmoon (1997)
# 100832  Sympathy for the Underdog (1971)
# 100833                     Hazard (2005)
# 100834                Blair Witch (2016)
# 100835                         31 (2016)
#
#                                              genres  userId_movieId  \
# 0       Adventure|Animation|Children|Comedy|Fantasy             NaN
# 1       Adventure|Animation|Children|Comedy|Fantasy             NaN
# 2       Adventure|Animation|Children|Comedy|Fantasy             NaN
# 3       Adventure|Animation|Children|Comedy|Fantasy             NaN
# 4       Adventure|Animation|Children|Comedy|Fantasy             NaN
# ...                                             ...             ...
# 100831                              Action|Thriller             NaN
# 100832                           Action|Crime|Drama             NaN
# 100833                        Action|Drama|Thriller             NaN
# 100834                              Horror|Thriller             NaN
# 100835                                       Horror             NaN
#
#         timestamp_y  tag
# 0               NaN  NaN
# 1               NaN  NaN
# 2               NaN  NaN
# 3               NaN  NaN
# 4               NaN  NaN
# ...             ...  ...
# 100831          NaN  NaN
# 100832          NaN  NaN
# 100833          NaN  NaN
# 100834          NaN  NaN
# 100835          NaN  NaN
#
# [100836 rows x 9 columns]

# %%
df_complete = ratings_movie_tags_df.merge(link_df,  how = 'left', on = 'movieId')

# %%
df_complete
# Out:
#         userId  movieId  rating  timestamp_x  \
# 0            1        1     4.0    964982703
# 1            5        1     4.0    847434962
# 2            7        1     4.5   1106635946
# 3           15        1     2.5   1510577970
# 4           17        1     4.5   1305696483
# ...        ...      ...     ...          ...
# 100831     610   160341     2.5   1479545749
# 100832     610   160527     4.5   1479544998
# 100833     610   160836     3.0   1493844794
# 100834     610   163937     3.5   1493848789
# 100835     610   163981     3.5   1493850155
#
#                                    title  \
# 0                       Toy Story (1995)
# 1                       Toy Story (1995)
# 2                       Toy Story (1995)
# 3                       Toy Story (1995)
# 4                       Toy Story (1995)
# ...                                  ...
# 100831                  Bloodmoon (1997)
# 100832  Sympathy for the Underdog (1971)
# 100833                     Hazard (2005)
# 100834                Blair Witch (2016)
# 100835                         31 (2016)
#
#                                              genres  userId_movieId  \
# 0       Adventure|Animation|Children|Comedy|Fantasy             NaN
# 1       Adventure|Animation|Children|Comedy|Fantasy             NaN
# 2       Adventure|Animation|Children|Comedy|Fantasy             NaN
# 3       Adventure|Animation|Children|Comedy|Fantasy             NaN
# 4       Adventure|Animation|Children|Comedy|Fantasy             NaN
# ...                                             ...             ...
# 100831                              Action|Thriller             NaN
# 100832                           Action|Crime|Drama             NaN
# 100833                        Action|Drama|Thriller             NaN
# 100834                              Horror|Thriller             NaN
# 100835                                       Horror             NaN
#
#         timestamp_y  tag   imdbId    tmdbId
# 0               NaN  NaN   114709     862.0
# 1               NaN  NaN   114709     862.0
# 2               NaN  NaN   114709     862.0
# 3               NaN  NaN   114709     862.0
# 4               NaN  NaN   114709     862.0
# ...             ...  ...      ...       ...
# 100831          NaN  NaN   118745   30948.0
# 100832          NaN  NaN    66806   90351.0
# 100833          NaN  NaN   798722   70193.0
# 100834          NaN  NaN  1540011  351211.0
# 100835          NaN  NaN  3835080  284564.0
#
# [100836 rows x 11 columns]

# %%
df_complete = df_complete.drop(columns = 'userId_movieId')

# %%
df_complete
# Out:
#         userId  movieId  rating  timestamp_x  \
# 0            1        1     4.0    964982703
# 1            5        1     4.0    847434962
# 2            7        1     4.5   1106635946
# 3           15        1     2.5   1510577970
# 4           17        1     4.5   1305696483
# ...        ...      ...     ...          ...
# 100831     610   160341     2.5   1479545749
# 100832     610   160527     4.5   1479544998
# 100833     610   160836     3.0   1493844794
# 100834     610   163937     3.5   1493848789
# 100835     610   163981     3.5   1493850155
#
#                                    title  \
# 0                       Toy Story (1995)
# 1                       Toy Story (1995)
# 2                       Toy Story (1995)
# 3                       Toy Story (1995)
# 4                       Toy Story (1995)
# ...                                  ...
# 100831                  Bloodmoon (1997)
# 100832  Sympathy for the Underdog (1971)
# 100833                     Hazard (2005)
# 100834                Blair Witch (2016)
# 100835                         31 (2016)
#
#                                              genres  timestamp_y  tag  \
# 0       Adventure|Animation|Children|Comedy|Fantasy          NaN  NaN
# 1       Adventure|Animation|Children|Comedy|Fantasy          NaN  NaN
# 2       Adventure|Animation|Children|Comedy|Fantasy          NaN  NaN
# 3       Adventure|Animation|Children|Comedy|Fantasy          NaN  NaN
# 4       Adventure|Animation|Children|Comedy|Fantasy          NaN  NaN
# ...                                             ...          ...  ...
# 100831                              Action|Thriller          NaN  NaN
# 100832                           Action|Crime|Drama          NaN  NaN
# 100833                        Action|Drama|Thriller          NaN  NaN
# 100834                              Horror|Thriller          NaN  NaN
# 100835                                       Horror          NaN  NaN
#
#          imdbId    tmdbId
# 0        114709     862.0
# 1        114709     862.0
# 2        114709     862.0
# 3        114709     862.0
# 4        114709     862.0
# ...         ...       ...
# 100831   118745   30948.0
# 100832    66806   90351.0
# 100833   798722   70193.0
# 100834  1540011  351211.0
# 100835  3835080  284564.0
#
# [100836 rows x 10 columns]
