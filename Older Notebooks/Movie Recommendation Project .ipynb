# %% [markdown]
# # Project Title
#
# **Authors:** Student 1, Student 2, Student 3
# ***

# %% [markdown]
# ## Overview
#
# A one-paragraph overview of the project, including the business problem, data, methods, results and recommendations.

# %% [markdown]
# ## Business Problem
#
# Summary of the business problem you are trying to solve, and the data questions that you plan to answer to solve them.
#
# ***
# Questions to consider:
# * What are the business's pain points related to this project?
# * How did you pick the data analysis question(s) that you did?
# * Why are these questions important from a business perspective?
# ***

# %% [markdown]
# ## Data Understanding
#
# Describe the data being used for this project.
# ***
# Questions to consider:
# * Where did the data come from, and how do they relate to the data analysis questions?
# * What do the data represent? Who is in the sample and what variables are included?
# * What is the target variable?
# * What are the properties of the variables you intend to use?
# ***

# %%
import pandas as pd

from surprise import Dataset, Reader, accuracy
from surprise.model_selection import cross_validate,GridSearchCV
from surprise.prediction_algorithms import SVD, SVDpp, NMF, BaselineOnly,\
                                            NormalPredictor, KNNBasic
from sklearn.model_selection import train_test_split
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import cross_validate
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## EDA

# %%
movies = pd.read_csv('./data/movies.csv')
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
movies.isna().sum()
# Out:
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
movies.title.duplicated().sum()
# Out:
# 5

# %%
movies.drop_duplicates(subset='title', inplace=True)

# %%
movies.title.duplicated().sum()
# Out:
# 0

# %%
movies.shape
# Out:
# (9737, 3)

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9737 rows x 3 columns]

# %%
movies[['title', 'year']] = movies.title.str.split('(', n=1, expand=True)
movies
# Out:
#       movieId                                title  \
# 0           1                           Toy Story
# 1           2                             Jumanji
# 2           3                    Grumpier Old Men
# 3           4                   Waiting to Exhale
# 4           5         Father of the Bride Part II
# ...       ...                                  ...
# 9737   193581  Black Butler: Book of the Atlantic
# 9738   193583               No Game No Life: Zero
# 9739   193585                               Flint
# 9740   193587        Bungo Stray Dogs: Dead Apple
# 9741   193609        Andrew Dice Clay: Dice Rules
#
#                                            genres   year
# 0     Adventure|Animation|Children|Comedy|Fantasy  1995)
# 1                      Adventure|Children|Fantasy  1995)
# 2                                  Comedy|Romance  1995)
# 3                            Comedy|Drama|Romance  1995)
# 4                                          Comedy  1995)
# ...                                           ...    ...
# 9737              Action|Animation|Comedy|Fantasy  2017)
# 9738                     Animation|Comedy|Fantasy  2017)
# 9739                                        Drama  2017)
# 9740                             Action|Animation  2018)
# 9741                                       Comedy  1991)
#
# [9737 rows x 4 columns]

# %%
movies['year'] = movies.year.str.replace(')', '')
movies
# Out:
#       movieId                                title  \
# 0           1                           Toy Story
# 1           2                             Jumanji
# 2           3                    Grumpier Old Men
# 3           4                   Waiting to Exhale
# 4           5         Father of the Bride Part II
# ...       ...                                  ...
# 9737   193581  Black Butler: Book of the Atlantic
# 9738   193583               No Game No Life: Zero
# 9739   193585                               Flint
# 9740   193587        Bungo Stray Dogs: Dead Apple
# 9741   193609        Andrew Dice Clay: Dice Rules
#
#                                            genres  year
# 0     Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                      Adventure|Children|Fantasy  1995
# 2                                  Comedy|Romance  1995
# 3                            Comedy|Drama|Romance  1995
# 4                                          Comedy  1995
# ...                                           ...   ...
# 9737              Action|Animation|Comedy|Fantasy  2017
# 9738                     Animation|Comedy|Fantasy  2017
# 9739                                        Drama  2017
# 9740                             Action|Animation  2018
# 9741                                       Comedy  1991
#
# [9737 rows x 4 columns]

# %%
movies = movies[['movieId', 'year', 'title', 'genres']]
movies
# Out:
#       movieId  year                                title  \
# 0           1  1995                           Toy Story
# 1           2  1995                             Jumanji
# 2           3  1995                    Grumpier Old Men
# 3           4  1995                   Waiting to Exhale
# 4           5  1995         Father of the Bride Part II
# ...       ...   ...                                  ...
# 9737   193581  2017  Black Butler: Book of the Atlantic
# 9738   193583  2017               No Game No Life: Zero
# 9739   193585  2017                               Flint
# 9740   193587  2018        Bungo Stray Dogs: Dead Apple
# 9741   193609  1991        Andrew Dice Clay: Dice Rules
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9737 rows x 4 columns]

# %%
movies['genres']=[row.strip().lower().replace('|',', ') for row in movies['genres']]
movies
# Out:
#       movieId  year                                title  \
# 0           1  1995                           Toy Story
# 1           2  1995                             Jumanji
# 2           3  1995                    Grumpier Old Men
# 3           4  1995                   Waiting to Exhale
# 4           5  1995         Father of the Bride Part II
# ...       ...   ...                                  ...
# 9737   193581  2017  Black Butler: Book of the Atlantic
# 9738   193583  2017               No Game No Life: Zero
# 9739   193585  2017                               Flint
# 9740   193587  2018        Bungo Stray Dogs: Dead Apple
# 9741   193609  1991        Andrew Dice Clay: Dice Rules
#
#                                                genres
# 0     adventure, animation, children, comedy, fantasy
# 1                        adventure, children, fantasy
# 2                                     comedy, romance
# 3                              comedy, drama, romance
# 4                                              comedy
# ...                                               ...
# 9737               action, animation, comedy, fantasy
# 9738                       animation, comedy, fantasy
# 9739                                            drama
# 9740                                action, animation
# 9741                                           comedy
#
# [9737 rows x 4 columns]

# %%
rating = pd.read_csv('./data/ratings.csv')
rating
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
rating['timestamp'] = pd.to_datetime(rating['timestamp'], unit='s')
rating
# Out:
#         userId  movieId  rating           timestamp
# 0            1        1     4.0 2000-07-30 18:45:03
# 1            1        3     4.0 2000-07-30 18:20:47
# 2            1        6     4.0 2000-07-30 18:37:04
# 3            1       47     5.0 2000-07-30 19:03:35
# 4            1       50     5.0 2000-07-30 18:48:51
# ...        ...      ...     ...                 ...
# 100831     610   166534     4.0 2017-05-03 21:53:22
# 100832     610   168248     5.0 2017-05-03 22:21:31
# 100833     610   168250     5.0 2017-05-08 19:50:47
# 100834     610   168252     5.0 2017-05-03 21:19:12
# 100835     610   170875     3.0 2017-05-03 21:20:15
#
# [100836 rows x 4 columns]

# %%
rating.isna().sum()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %%
rating.duplicated().sum()
# Out:
# 0

# %%
rating['rating'].value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: rating, dtype: int64

# %%
rating['rating'].value_counts(normalize=True)
# Out:
# 4.0    0.265957
# 3.0    0.198808
# 5.0    0.131015
# 3.5    0.130271
# 4.5    0.084801
# 2.0    0.074884
# 2.5    0.055040
# 1.0    0.027877
# 1.5    0.017762
# 0.5    0.013586
# Name: rating, dtype: float64

# %%
rating.shape
# Out:
# (100836, 4)

# %%
movie_rating = movies.merge(rating, on='movieId', how='outer')
movie_rating
# Out:
#         movieId  year       title  \
# 0             1  1995  Toy Story
# 1             1  1995  Toy Story
# 2             1  1995  Toy Story
# 3             1  1995  Toy Story
# 4             1  1995  Toy Story
# ...         ...   ...         ...
# 100849    64997   NaN         NaN
# 100850   144606   NaN         NaN
# 100851   147002   NaN         NaN
# 100852    26958   NaN         NaN
# 100853   168358   NaN         NaN
#
#                                                  genres  userId  rating  \
# 0       adventure, animation, children, comedy, fantasy     1.0     4.0
# 1       adventure, animation, children, comedy, fantasy     5.0     4.0
# 2       adventure, animation, children, comedy, fantasy     7.0     4.5
# 3       adventure, animation, children, comedy, fantasy    15.0     2.5
# 4       adventure, animation, children, comedy, fantasy    17.0     4.5
# ...                                                 ...     ...     ...
# 100849                                              NaN    68.0     2.5
# 100850                                              NaN   111.0     4.0
# 100851                                              NaN   318.0     4.0
# 100852                                              NaN   509.0     3.5
# 100853                                              NaN   514.0     2.5
#
#                  timestamp
# 0      2000-07-30 18:45:03
# 1      1996-11-08 06:36:02
# 2      2005-01-25 06:52:26
# 3      2017-11-13 12:59:30
# 4      2011-05-18 05:28:03
# ...                    ...
# 100849 2008-12-28 20:55:15
# 100850 2018-01-31 23:27:37
# 100851 2017-08-08 15:45:52
# 100852 2015-07-04 17:42:33
# 100853 2018-08-11 00:06:10
#
# [100854 rows x 7 columns]

# %%
movie_rating.isna().sum()
# Out:
# movieId       0
# year         23
# title         6
# genres        6
# userId       18
# rating       18
# timestamp    18
# dtype: int64

# %%
movie_rating.dropna(inplace=True)

# %%
movie_rating
# Out:
#         movieId  year                                title  \
# 0             1  1995                           Toy Story
# 1             1  1995                           Toy Story
# 2             1  1995                           Toy Story
# 3             1  1995                           Toy Story
# 4             1  1995                           Toy Story
# ...         ...   ...                                  ...
# 100843   193581  2017  Black Butler: Book of the Atlantic
# 100844   193583  2017               No Game No Life: Zero
# 100845   193585  2017                               Flint
# 100846   193587  2018        Bungo Stray Dogs: Dead Apple
# 100847   193609  1991        Andrew Dice Clay: Dice Rules
#
#                                                  genres  userId  rating  \
# 0       adventure, animation, children, comedy, fantasy     1.0     4.0
# 1       adventure, animation, children, comedy, fantasy     5.0     4.0
# 2       adventure, animation, children, comedy, fantasy     7.0     4.5
# 3       adventure, animation, children, comedy, fantasy    15.0     2.5
# 4       adventure, animation, children, comedy, fantasy    17.0     4.5
# ...                                                 ...     ...     ...
# 100843               action, animation, comedy, fantasy   184.0     4.0
# 100844                       animation, comedy, fantasy   184.0     3.5
# 100845                                            drama   184.0     3.5
# 100846                                action, animation   184.0     3.5
# 100847                                           comedy   331.0     4.0
#
#                  timestamp
# 0      2000-07-30 18:45:03
# 1      1996-11-08 06:36:02
# 2      2005-01-25 06:52:26
# 3      2017-11-13 12:59:30
# 4      2011-05-18 05:28:03
# ...                    ...
# 100843 2018-09-16 14:44:42
# 100844 2018-09-16 14:52:25
# 100845 2018-09-16 14:56:45
# 100846 2018-09-16 15:00:21
# 100847 2018-09-17 04:13:26
#
# [100813 rows x 7 columns]

# %%
links = pd.read_csv('./data/links.csv')
links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
tags = pd.read_csv('./data/tags.csv')
tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
final_movie_rating = movie_rating.merge(tags, on='movieId', how='outer')
final_movie_rating
# Out:
#         movieId  year       title  \
# 0             1  1995  Toy Story
# 1             1  1995  Toy Story
# 2             1  1995  Toy Story
# 3             1  1995  Toy Story
# 4             1  1995  Toy Story
# ...         ...   ...         ...
# 285756    34482   NaN         NaN
# 285757    85565   NaN         NaN
# 285758   156605   NaN         NaN
# 285759   156605   NaN         NaN
# 285760   156605   NaN         NaN
#
#                                                  genres  userId_x  rating  \
# 0       adventure, animation, children, comedy, fantasy       1.0     4.0
# 1       adventure, animation, children, comedy, fantasy       1.0     4.0
# 2       adventure, animation, children, comedy, fantasy       1.0     4.0
# 3       adventure, animation, children, comedy, fantasy       5.0     4.0
# 4       adventure, animation, children, comedy, fantasy       5.0     4.0
# ...                                                 ...       ...     ...
# 285756                                              NaN       NaN     NaN
# 285757                                              NaN       NaN     NaN
# 285758                                              NaN       NaN     NaN
# 285759                                              NaN       NaN     NaN
# 285760                                              NaN       NaN     NaN
#
#                timestamp_x  userId_y               tag   timestamp_y
# 0      2000-07-30 18:45:03     336.0             pixar  1.139046e+09
# 1      2000-07-30 18:45:03     474.0             pixar  1.137207e+09
# 2      2000-07-30 18:45:03     567.0               fun  1.525286e+09
# 3      1996-11-08 06:36:02     336.0             pixar  1.139046e+09
# 4      1996-11-08 06:36:02     474.0             pixar  1.137207e+09
# ...                    ...       ...               ...           ...
# 285756                 NaT     474.0  In Netflix queue  1.137202e+09
# 285757                 NaT     543.0            Comedy  1.377022e+09
# 285758                 NaT     567.0            quirky  1.525283e+09
# 285759                 NaT     567.0             sweet  1.525283e+09
# 285760                 NaT     567.0       understated  1.525283e+09
#
# [285761 rows x 10 columns]

# %%
final_movie_rating.isna().sum()
# Out:
# movieId            0
# year              24
# title             24
# genres            24
# userId_x          24
# rating            24
# timestamp_x       24
# userId_y       52527
# tag            52527
# timestamp_y    52527
# dtype: int64

# %%
final_movie_rating.dropna(inplace=True)
final_movie_rating
# Out:
#         movieId  year                     title  \
# 0             1  1995                Toy Story
# 1             1  1995                Toy Story
# 2             1  1995                Toy Story
# 3             1  1995                Toy Story
# 4             1  1995                Toy Story
# ...         ...   ...                       ...
# 285699   187595  2018  Solo: A Star Wars Story
# 285724   193565  2010       Gintama: The Movie
# 285725   193565  2010       Gintama: The Movie
# 285726   193565  2010       Gintama: The Movie
# 285727   193565  2010       Gintama: The Movie
#
#                                                  genres  userId_x  rating  \
# 0       adventure, animation, children, comedy, fantasy       1.0     4.0
# 1       adventure, animation, children, comedy, fantasy       1.0     4.0
# 2       adventure, animation, children, comedy, fantasy       1.0     4.0
# 3       adventure, animation, children, comedy, fantasy       5.0     4.0
# 4       adventure, animation, children, comedy, fantasy       5.0     4.0
# ...                                                 ...       ...     ...
# 285699              action, adventure, children, sci-fi     586.0     5.0
# 285724                action, animation, comedy, sci-fi     184.0     3.5
# 285725                action, animation, comedy, sci-fi     184.0     3.5
# 285726                action, animation, comedy, sci-fi     184.0     3.5
# 285727                action, animation, comedy, sci-fi     184.0     3.5
#
#                timestamp_x  userId_y        tag   timestamp_y
# 0      2000-07-30 18:45:03     336.0      pixar  1.139046e+09
# 1      2000-07-30 18:45:03     474.0      pixar  1.137207e+09
# 2      2000-07-30 18:45:03     567.0        fun  1.525286e+09
# 3      1996-11-08 06:36:02     336.0      pixar  1.139046e+09
# 4      1996-11-08 06:36:02     474.0      pixar  1.137207e+09
# ...                    ...       ...        ...           ...
# 285699 2018-06-25 04:05:56      62.0  star wars  1.528935e+09
# 285724 2018-09-16 11:49:14     184.0      anime  1.537099e+09
# 285725 2018-09-16 11:49:14     184.0     comedy  1.537099e+09
# 285726 2018-09-16 11:49:14     184.0    gintama  1.537099e+09
# 285727 2018-09-16 11:49:14     184.0   remaster  1.537099e+09
#
# [233210 rows x 10 columns]

# %%
final_movie_rating = final_movie_rating.drop(['userId_y', 'timestamp_y'], axis=1)
final_movie_rating
# Out:
#         movieId  year                     title  \
# 0             1  1995                Toy Story
# 1             1  1995                Toy Story
# 2             1  1995                Toy Story
# 3             1  1995                Toy Story
# 4             1  1995                Toy Story
# ...         ...   ...                       ...
# 285699   187595  2018  Solo: A Star Wars Story
# 285724   193565  2010       Gintama: The Movie
# 285725   193565  2010       Gintama: The Movie
# 285726   193565  2010       Gintama: The Movie
# 285727   193565  2010       Gintama: The Movie
#
#                                                  genres  userId_x  rating  \
# 0       adventure, animation, children, comedy, fantasy       1.0     4.0
# 1       adventure, animation, children, comedy, fantasy       1.0     4.0
# 2       adventure, animation, children, comedy, fantasy       1.0     4.0
# 3       adventure, animation, children, comedy, fantasy       5.0     4.0
# 4       adventure, animation, children, comedy, fantasy       5.0     4.0
# ...                                                 ...       ...     ...
# 285699              action, adventure, children, sci-fi     586.0     5.0
# 285724                action, animation, comedy, sci-fi     184.0     3.5
# 285725                action, animation, comedy, sci-fi     184.0     3.5
# 285726                action, animation, comedy, sci-fi     184.0     3.5
# 285727                action, animation, comedy, sci-fi     184.0     3.5
#
#                timestamp_x        tag
# 0      2000-07-30 18:45:03      pixar
# 1      2000-07-30 18:45:03      pixar
# 2      2000-07-30 18:45:03        fun
# 3      1996-11-08 06:36:02      pixar
# 4      1996-11-08 06:36:02      pixar
# ...                    ...        ...
# 285699 2018-06-25 04:05:56  star wars
# 285724 2018-09-16 11:49:14      anime
# 285725 2018-09-16 11:49:14     comedy
# 285726 2018-09-16 11:49:14    gintama
# 285727 2018-09-16 11:49:14   remaster
#
# [233210 rows x 8 columns]

# %%
final_movie_rating['rating'].value_counts()
# Out:
# 4.0    64781
# 5.0    63845
# 4.5    31499
# 3.0    28550
# 3.5    22895
# 2.0     7955
# 2.5     6488
# 1.0     3721
# 0.5     1908
# 1.5     1568
# Name: rating, dtype: int64

# %% [markdown]
# ### decide to use movie_rating dataset because tag gives too many duplicates on rating

# %%
movie_rating
# Out:
#         movieId  year                                title  \
# 0             1  1995                           Toy Story
# 1             1  1995                           Toy Story
# 2             1  1995                           Toy Story
# 3             1  1995                           Toy Story
# 4             1  1995                           Toy Story
# ...         ...   ...                                  ...
# 100843   193581  2017  Black Butler: Book of the Atlantic
# 100844   193583  2017               No Game No Life: Zero
# 100845   193585  2017                               Flint
# 100846   193587  2018        Bungo Stray Dogs: Dead Apple
# 100847   193609  1991        Andrew Dice Clay: Dice Rules
#
#                                                  genres  userId  rating  \
# 0       adventure, animation, children, comedy, fantasy     1.0     4.0
# 1       adventure, animation, children, comedy, fantasy     5.0     4.0
# 2       adventure, animation, children, comedy, fantasy     7.0     4.5
# 3       adventure, animation, children, comedy, fantasy    15.0     2.5
# 4       adventure, animation, children, comedy, fantasy    17.0     4.5
# ...                                                 ...     ...     ...
# 100843               action, animation, comedy, fantasy   184.0     4.0
# 100844                       animation, comedy, fantasy   184.0     3.5
# 100845                                            drama   184.0     3.5
# 100846                                action, animation   184.0     3.5
# 100847                                           comedy   331.0     4.0
#
#                  timestamp
# 0      2000-07-30 18:45:03
# 1      1996-11-08 06:36:02
# 2      2005-01-25 06:52:26
# 3      2017-11-13 12:59:30
# 4      2011-05-18 05:28:03
# ...                    ...
# 100843 2018-09-16 14:44:42
# 100844 2018-09-16 14:52:25
# 100845 2018-09-16 14:56:45
# 100846 2018-09-16 15:00:21
# 100847 2018-09-17 04:13:26
#
# [100813 rows x 7 columns]

# %%
movie_rating['rating'].value_counts()
# Out:
# 4.0    26813
# 3.0    20044
# 5.0    13207
# 3.5    13132
# 4.5     8549
# 2.0     7550
# 2.5     5548
# 1.0     2810
# 1.5     1791
# 0.5     1369
# Name: rating, dtype: int64

# %% [markdown]
# stick with movie_rating

# %% [markdown]
# ## Data Preparation
#
# Describe and justify the process for preparing the data for analysis.
#
# ***
# Questions to consider:
# * Were there variables you dropped or created?
# * How did you address missing values or outliers?
# * Why are these choices appropriate given the data and the business problem?
# ***

# %%
# Here you run your code to clean the data

# %% [markdown]
# ## Data Modeling
# Describe and justify the process for analyzing or modeling the data.
#
# ***
# Questions to consider:
# * How did you analyze or model the data?
# * How did you iterate on your initial approach to make it better?
# * Why are these choices appropriate given the data and the business problem?
# ***

# %%
# Here you run your code to model the data

# %% [markdown]
# ## Evaluation
# Evaluate how well your work solves the stated business problem.
#
# ***
# Questions to consider:
# * How do you interpret the results?
# * How well does your model fit your data? How much better is this than your baseline model?
# * How confident are you that your results would generalize beyond the data you have?
# * How confident are you that this model would benefit the business if put into use?
# ***

# %% [markdown]
# ## Conclusions
# Provide your conclusions about the work you've done, including any limitations or next steps.
#
# ***
# Questions to consider:
# * What would you recommend the business do as a result of this work?
# * What are some reasons why your analysis might not fully solve the business problem?
# * What else could you do in the future to improve this project?
# ***
